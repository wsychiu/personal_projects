# %%
# sources?
# https://www.api-football.com/documentation-v3#section/Introduction
# https://www.statshub.com/league/premier-league/1
# https://api-docs.statushub.com/api-v3-openapi/section/the-statushub-management-api-v3/statushub-regions-and-api-url
